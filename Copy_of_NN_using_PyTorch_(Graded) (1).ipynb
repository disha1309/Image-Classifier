# %% [markdown]
# # **PyTorch Implementation of Neural Networks**
# In this week's graded assignment, you will implement a neural network that will perform binary classification on a set of images (ie. is or is not).
#
# You are to only write/modify the code in between consecutive `# <START>` and `# <END>` comments. DO NOT modify other parts of the notebook, your assignments will not be graded otherwise.
#
# ```python
# "Don't modify any code here"
#
# # <START>
# "YOUR CODE GOES HERE!"
# # <END>
#
# "Don't modify any code here"
# ```
# ## **Before you begin**
# Before you start with the assignment, you will have to upload the images that you will classify to your Google Drive.
# You will be able to find the compressed folder named **"pizza_vs_not"** on both the GitHub repo and the Week 1 MS Teams channel.
# Download the file, unzip it, and then upload it to your Drive.
#
# ### **Make sure to upload to the same account that you are using on Colab, otherwise you won't be able to access the files**

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# ## **Mounting Google Drive**
# First, we need to import the dataset of images from your Google Drive. To do so, **run the below cell**. This will mount your Drive to the running Colab instance. Then, you will be able to access all your Google Drive data in this notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Import the Libraries**
#
# Run the cell below to import all the necessary libraries for building the neural network using PyTorch.
# You will primarily use the **`nn` module** of the **PyTorch** library for building the neural network.

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %% [markdown]
# ## **Importing the Dataset**
#
# We now need to import the dataset from the Google Drive. Below given is a function named `getdata`, which takes the path of the folder from which data is to be imported as its argument.
#
# You are required to give in the path of the folder in which the images of `pizza` and `not_pizza` are saved in your Google Drive. Locate the path using the Colab File Explorer (the file icon in the sidebar).
#
# The `getdata` function reads each image stored at the given path and converts and stores it as a PyTorch Tensor.
#
# _Note: This cell may take a while to finish running_
# <details>
#   <summary>Hint</summary>
#   The Google Drive was mounted to the location "/content/drive", containing the folder "My Drive", which corresponds to your actual Google Drive.
# </details>

# %%
def getdata(path):
  data = torch.tensor([])
  file_list = os.listdir(path)
  for file_name in file_list[:350]:
    image_path = os.path.join(path, file_name)
    image = mpimg.imread(image_path)
    imageData = torch.from_numpy(image).long()
    data = torch.cat((data, imageData.unsqueeze(0)), dim=0)
  return data

# <START>
pizza_path = '/content/drive/MyDrive/pizza_vs_not/pizza'
not_pizza_path = '/content/drive/MyDrive/pizza_vs_not/not_pizza'
# <END>

not_pizza_data = getdata(not_pizza_path)
pizza_data = getdata(pizza_path)

# %% [markdown]
# Using the next cell, you can preview the images you've just loaded

# %%
# Change values of index, data
# <START>
index = 200 # 0 to 349
data = not_pizza_data # pizza_data (or) not_pizza_data
# <END>

plt.imshow(data[index].int())

# %% [markdown]
# ## **Preprocessing the dataset**
#
# Before we begin working with the neural network, we need to make sure our data (in this case, $64\times64$ RGB images) is in a format that neural networks can work with.
#
# First, we create a `train_data` collection of images for training the neural network, and another collection `test_data` that will then be used to check the accuracy of the trained neural network. We do this by taking slices of the total data and concatenating them.

# %%
train_data = torch.cat((pizza_data[:300], not_pizza_data[:200]), dim = 0)
test_data = torch.cat((pizza_data[300:350], not_pizza_data[200:250]), dim = 0)
print(test_data.shape)
# Out:
# torch.Size([100, 64, 64, 3])

# %% [markdown]
# Each image is still stored as a $64\times64\times3$ tensor ie. a $64\times64$ array of 3 numbers - the RGB values of the pixel, taking values between **0 to 255**.
# You need to flatten the images in both datasets to make *reshaped* data, and normalise them to get the *final* data we will use to train and test the model.
#
# <details>
#   <summary>Hint</summary>
#   Use the reshape command to flatten the dataset and then normalise the flattened dataset (ie. make sure all the values lie between 0 and 1).
# </details>

# %%
# <START>
x_data = np.array([np.array(train_data[i]) for i in range(0,len(train_data))])
y_data = np.array([np.array(test_data[i]) for i in range(0,len(test_data))])
reshaped_train_data = torch.from_numpy(x_data.flatten().reshape(500, 12288))
reshaped_test_data = torch.from_numpy(y_data.flatten().reshape(100, 12288))

x_mean = torch.mean(reshaped_train_data)
y_mean = torch.mean(reshaped_test_data)
x_std = torch.std(reshaped_train_data)
y_std = torch.std(reshaped_test_data)
final_train_data = (reshaped_train_data - x_mean)/x_std
final_test_data = (reshaped_test_data - y_mean)/y_std

# <END>

print(final_train_data.shape, final_test_data.shape)
# Out:
# torch.Size([500, 12288]) torch.Size([100, 12288])

# %% [markdown]
# Now that you have made two datasets, you need to make their corresponding `labels` Tensors, which store the true output for each image (whether or not it is a pizza).
#
# In the `labels` Tensor, use **`1`** for images that belong to `pizza` and **`0`** for `not_pizza`. (Try to use the concatenate function instead of simply using *for* loops for generating the `labels` Tensor !!)
#
# **Remember** to ensure that both `train_labels` and `test_labels` are 2D tensors of appropriate dimensions. Otherwise, it can cause issues ahead.

# %%
# <START>
shape_pizza_train = (300, 1)
shape_notpizza_train = (200,1)
shape_pizza_test = (50, 1)
shape_notpizza_test = (50, 1)
train_labels = torch.cat((torch.ones(shape_pizza_train), torch.zeros(shape_notpizza_train)),dim = 0)

test_labels = torch.cat((torch.ones(shape_pizza_test), torch.zeros(shape_notpizza_test) ), dim = 0)

# <END>

print(train_labels.shape, test_labels.shape)
# Out:
# torch.Size([500, 1]) torch.Size([100, 1])

# %% [markdown]
# ##**Building the Neural Network**
#
# Now, we will start making the actual neural network.
#
# First, initialise the hyperparameters of the neural network.
# Here, we are going to make a 3 layer neural network (i.e., 1 input layer, 2 hidden layers and 1 output layer). The first hidden layer will have 10 nodes, while the second will have 12.
# Enter the number of input parameters, number of nodes of each hidden layer and the number of output parameters.

# %%
# <START>

D_in = 12288
H1 = 100
H2 = 60
H3 = 30
D_out = 1

# <END>

# %% [markdown]
# Now you will make the actual model. The Model includes the use of `Linear` function at each layer, alongside non-linear activation functions.
#
# We are going to use `ReLU` functions as activation functions for the input and the first hidden layer and `Sigmoid` function for the final output, as we want an output between 0 and 1.
#
# (Hint: `Linear`, `ReLU` and `Sigmoid` functions are a part of the `nn` module of the **PyTorch** library)

# %%
from torch.nn.modules.activation import ReLU
#s=nn.Sigmoid()
model = torch.nn.Sequential(
    # Do not hard-code any values, use the variables from the previous cell
    # <START>
    nn.Linear(D_in, H1),
    nn.ReLU(),
    nn.Linear(H1,H2),
    nn.ReLU(),
    nn.Linear(H2,H3),
    nn.ReLU(),
    nn.Linear(H3,D_out),
    nn.Sigmoid()

    # <END>

)

# %%
model(final_train_data[400]) #To check if the model works
# Out:
# tensor([0.5126], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# After making the model, we defined the `loss_fn` , i.e., the loss function as the Binary Cross Entropy Loss.
#
# Here, you will implement gradient descent.
#
# The `learning_rate` is the step size which the neural network takes when it updates the parameters of the network. (Try to explore various values of step size. Values similar to 0.005 are usually suitable). Also play around with the number of `iterations` the gradient descent algorithm needs to take.
#
# **Follow the steps given as per the comments.**
#
# *Note: When you run the code, it could take about 5 minutes for the network to finish training.*

# %%
from torch.autograd import grad
loss_fn = nn.BCELoss()
# <START>

learning_rate = 0.005
iterations = 10000
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#layers=[x.data for x in model.parameters()]
'''w1 = layers[0]
b1 = layers[1]
w2 = layers[2]
b2 = layers[3]
w3 = layers[4]
b3 = layers[5]
w1.requires_grad = True
w2.requires_grad = True
w3.requires_grad = True
b1.requires_grad = True
b2.requires_grad = True
b3.requires_grad = True
w1.retain_grad()
print(w1.is_leaf)
print(w1.grad)'''
for t in range(iterations):
  for i in range(500):
    # call the model on the dataset
    y_pred = model (final_train_data[i])
    #calculate the loss
    loss = loss_fn(y_pred, train_labels[i])
    if t%1000 == 1:
        print(loss)
    #calculate the gradients (dont forget to reset the gradients before you begin)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    #print(model[0].weight.grad)

    # update the values of the parameters
    '''
    outputs = []
    accuracy = 0.0
    with torch.no_grad():
      for k in range(100):
            #images, labels = data
            # run the model on the test set to predict labels
            outputs.append = model(final_test_data[k])
            # the label with the highest energy will be our prediction
            _, predicted = torch.max(outputs.data, 1)
            #total += labels.size(0)
            accuracy += (predicted == test_labels[i]).sum().item()
    '''

# <END>
torch.save(model, 'model_best.pt')
# Out:
# tensor(7.4802, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.7048, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0692, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3544, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.4058, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.9124, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2277, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1422, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2629, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0423, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3106, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0798, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0846, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6921, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1391, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.4093, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0321, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2601, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1670, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0788, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.0497, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1080, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0036, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0683, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0083, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0267, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0288, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0096, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1302, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0243, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0119, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0012, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0352, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0005, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1365, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.6940, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.6596, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1201, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0415, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0098, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0386, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0440, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0401, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0059, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0090, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0415, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0078, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0052, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0025, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0500, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0078, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0501, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1010, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0167, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0494, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0087, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1162, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0140, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0047, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.5059, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0090, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2517e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0312, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0463, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0046, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0002, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0765, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1060, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0004, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0013, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1186, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0320, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0018, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2201, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0135, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.8716e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0257, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0205, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.4103, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0107, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0388, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0686, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0165, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0741, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0036, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0151, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0246, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.7160e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2119, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0082, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0116, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0149, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0848e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0064, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.2068e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0454, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0052, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0015, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0118, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0045, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0008, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0016, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.5820e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0770, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0461, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0022, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0012, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0073, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0139, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.6757e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0024, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0956, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0622, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0071, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0064, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0002, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0246, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0023, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1893, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0016, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0034, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0458, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0331, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0278, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0056, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.2005e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0022, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0012, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0018, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0037, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0244, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0013, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0058, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0036, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0012, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1086, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0010, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.4305e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0082, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.7160e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.1526e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0006, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0090, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0905, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0094, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0025, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0017, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.3447e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0273, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0031, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0004, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0013, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0002, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.8744e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0051, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.8386e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.7131, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.9501e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0024, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0250, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0005, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0006, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0078, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.9756, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.7790e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.0623e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.5367e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.0027e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0023, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0619, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.9326e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.1185e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0067, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0010, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0044, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0397, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.6560e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0010, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0129, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0195, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0392, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0002, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.7221e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0025, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0058, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.3113e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1527, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.8876e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0488, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0064, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.6416e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0004, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0002, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0729e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0008, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0008, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.2292e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.2650e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0039, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0006, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1325e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0006, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.3352e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0347, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.5034e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.4677e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0020, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.4509e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0009, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0016, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.7881e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.1526e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0560, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1261, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.8667e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0006, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.5763e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0023, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0014, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.3447e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0009, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0004, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.3352e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0160, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0018, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.7684e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0038, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.1696e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0010, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.0994e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0021, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3842e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0009, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0132, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.5300e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0043, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0108, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0007, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.1724e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.4782e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0006, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.9074e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.8876e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0004, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.8147e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0028, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.5596e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.7909e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0007, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.7684e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.9871e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.6029e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2398e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0016, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0002, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.2825e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0088, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.1989e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.6507e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.9130e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1269, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.9074e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0015, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.4285e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1444e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1087e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0002, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0999, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1096, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.6068, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2129, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.6598e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0013, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.1989e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.0916, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2324, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.6482, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2955, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.6058, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1550, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0170, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2871, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.6356, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3362, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.6170, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2179, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.5016, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0450, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.5592, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2945, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.9017, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2855, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0364, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3204, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2159, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2264, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3101, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0705, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1532, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0847, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2397, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1653, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0364, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1207, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.5184, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.4040, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0693, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.5141, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.8614, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0156, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2805, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0760, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0290, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.4874, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0413, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1049, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2705, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2781, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3602, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0060, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0371, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0578, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.5196, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0207, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1949, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.4011, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0991, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0777, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1053, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0499, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1096, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2095, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2462, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0311, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0436, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0813, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3058, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0533, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0212, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1265, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0316, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0033, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1542, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1042, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1028, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0092, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0087, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2155, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0701, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0014, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0825, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0105, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0489, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3985, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0005, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0176, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1303, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0080, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0873, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0026, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0107, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0086, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0298, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.4043, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0940, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0500, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0231, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0108, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0240, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0107, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0002, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1135, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0100, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0787, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0026, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0015, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0523, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0167, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0996, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0808, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0690, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0017, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0291, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0183, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0197, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0404, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0898, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0209, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0758, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0056, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1539, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0269, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0516, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0090, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0345, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.5086e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.8824, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0240, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0063, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.2725, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0245, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0109, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0026, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0011, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0083, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3110, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0017, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0082, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0035, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0682, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0112, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0090, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0014, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0006, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0059, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0110, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0189, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0098, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0094, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3412, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0022, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0448, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0532, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0126, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0023, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0155, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0069, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0159, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0397, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0174, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1368, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0237, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0029, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1894, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0355, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0015, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0253, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0014, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0052, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0008, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0299, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0180, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0030, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0244, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0270, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0104, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.1271, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0695, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0626, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0044, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0009, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0919, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0040, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0013, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0072, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0135, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0012, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0361, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0138, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0453, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0038, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0057, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0012, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0016, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0172, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0578, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0631, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0030, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0632, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0135, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0027, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.0437, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6689e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.0266e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3842e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.4943e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.5763e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.3447e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3842e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0729e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0729e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.9339e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6689e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.5763e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.9431e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.4571e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.6029e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.5367e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.1260e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3842e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.8876e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.6294e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3842e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.9605e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.3828e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.1526e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.4108e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.2650e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.2797e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.4108e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.5831e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.5497e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.2915e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.5763e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.2452e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.5763e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.0266e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3842e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.2452e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.7524e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.3113e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.7684e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.8876e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.7486e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.7684e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.0334e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.5497e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.8678e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.5763e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.2984e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1921e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0729e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1802e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.8239e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.6757e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.4424e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6332e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0., grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.2747e-16, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.5082e-18, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0973e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.5205e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.4509e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.2974e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.5427e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.5346e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.6207e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.1510e-18, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1848e-14, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.6460e-15, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3528e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.0001e-23, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1720e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.8137e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.8001e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.2566e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.8951e-21, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.9414e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.8257e-10, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.1448e-27, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.4630e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.1063e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.4789e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.5667e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.1431e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.3073e-17, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.0589e-22, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2936e-24, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.5312e-15, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.9156e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6378e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.6766e-15, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.7808e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1889e-16, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.8150e-18, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0327e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.8242e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.6141e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.4280e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.5179e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3974e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.3592e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6141e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6918e-10, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3113e-15, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.2610e-15, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.2080e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2632e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1051e-17, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.9219e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2745e-10, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.0991e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.1543e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.4444e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.3555e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.0429e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.7080e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.8625e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.1650e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2898e-10, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2277e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.0384e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.0833e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.6443e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.7346e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.1945e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.3720e-23, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1625e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.6718e-12, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.4300e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6307e-16, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.6931e-12, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.4619e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.8718e-15, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.2331e-15, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2383e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.3315e-10, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.2405e-10, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2930e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.8310e-25, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.7521e-20, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.0266e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.3318e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.8058e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2213e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.1508e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.1008e-12, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.3396e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.2625e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.1240e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.9267e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.2876e-10, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.3021e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.8486e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1490e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.5405e-28, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.8338e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.8883e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1869e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.9368e-12, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.9848e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.3505e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.9556e-10, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.2673e-15, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.5542e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.7750e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.0291e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0536e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.7255e-14, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.9668e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.7924e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.5418e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.2671e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.4226e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1294e-15, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.4868e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.1627e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.5230e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.4189e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.7081e-17, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.4237e-29, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.4635e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.4958e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2266e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.5652e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6450e-10, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.9171e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.3144e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.7925e-12, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0273e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.5924e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.9753e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2862e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.0170e-12, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.7705e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1359e-14, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.3190e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.4672e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.0029e-14, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.7377e-14, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.7070e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.0239e-14, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.6830e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6003e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.7508e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3488e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1229e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.8480e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.3322e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.9057e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.0069e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.8017e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.2670e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.0242e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.8941e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.8084e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.1749e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.9767e-14, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.7628e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.1906e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.3503e-12, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.6262e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.4654e-23, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3218e-07, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.8853e-10, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3873e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.6037e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.1273e-12, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1645e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3229e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.8224e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.2953e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2993e-22, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.9930e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.1098e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.7502e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(6.2437e-15, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.6278e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.0833e-08, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.6079e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.2187e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2525e-05, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(4.1242e-11, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.0021e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.8072e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.2121e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.3164e-13, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(2.1748e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.8461e-17, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.3318e-12, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.9165e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.4255e-09, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(3.5807e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(5.3152e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(9.5837e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(7.6787e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(1.4181e-17, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(8.2007e-06, grad_fn=<BinaryCrossEntropyBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-aa184fb5e0a7> in <cell line: 24>()
#      25   for i in range(500):
#      26     # call the model on the dataset
# ---> 27     y_pred = model (final_train_data[i])
#      28     #calculate the loss
#      29     loss = loss_fn(y_pred, train_labels[i])
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# ## **Checking the Results**
# Now that we have used the training set to train the network, we shall use the test set to check how the neural network performs with new inputs.

# %%
# Change values of index
# <START>
index = 60 #0 to 99
# <END>

plt.imshow(test_data[index].int())
print (f'According to the neural network, index = {index} is {"a pizza" if model(final_test_data[index]) > 0.5 else "not a pizza"}' )
# Out:
# According to the neural network, index = 60 is not a pizza

# %% [markdown]
# # To quantize how accurately the neural network is able to classify images, we have defined a helper `predict` function that takes a dataset and returns the fraction of times the neural network correctly classified the image.
#
# Complete the function such that it prints the correct accuracy of its predictions.

# %%
def predict(model, data, labels):

    probabilities = model(data)

    # <START>

    # generate the predictions tensor using the probabilities variable, which indicates the prediction made by the model for the given data using 0 and 1

    m = nn.Softmax(dim = 1)
    predictions = m(probabilities)
    # <END>

    print("Accuracy: "  + str(torch.sum((predictions == labels)).item()/predictions.shape[0]))

# %% [markdown]
# **Run** the cell below to find out the accuracy of your model for the training and test datasets.

# %%
predict(model, final_train_data, train_labels)
predict(model,final_test_data,test_labels)
print("Done!")
# Out:
# Accuracy: 0.6
# Accuracy: 0.5
# Done!

# %% [markdown]
# ## **Extra Content (Optional)**
# ##### **These are extra exercises you can try after submitting the assignment, for you to try on your own. Feel free to approach us with any doubts, but DO NOT make these changes to the notebook before you submit**
# - Try varying things like the number and size of the hidden layers, and seeing how that affects the accuracy of the network.
# - Along with `pizza` and `not_pizza`, you should see another folder `other_dishes` in the dataset. Try using it in place of `not_pizza`. What changes do you see? Why do you think this happens?
